# %%
import numpy as np 
from matplotlib import pyplot as plt 
import pandas as pd

# %%
main_df = pd.read_csv('main_df.csv')

# %%
set(main_df['month_sale'])
# Out:
# {0.0,
#  0.2,
#  1.0,
#  1.2,
#  1.25,
#  1.5,
#  2.0,
#  2.2,
#  2.35,
#  3.0,
#  3.2,
#  4.0,
#  4.2,
#  5.0,
#  5.2,
#  5.4,
#  6.0,
#  6.5200000000000005,
#  7.0,
#  7.3,
#  8.0,
#  8.2,
#  8.3,
#  8.57,
#  9.0,
#  10.0,
#  10.08,
#  10.2,
#  10.72,
#  11.0,
#  11.5,
#  12.0,
#  12.2,
#  13.0,
#  13.2,
#  14.0,
#  15.0,
#  15.2,
#  16.0,
#  16.2,
#  16.7,
#  17.0,
#  18.0,
#  18.7,
#  19.0,
#  19.2,
#  20.0,
#  20.62,
#  21.0,
#  22.0,
#  23.0,
#  24.0,
#  24.85,
#  25.0,
#  26.0,
#  27.0,
#  27.03,
#  27.2,
#  28.0,
#  29.0,
#  30.0,
#  30.2,
#  31.0,
#  31.1,
#  32.0,
#  33.0,
#  33.2,
#  34.0,
#  35.0,
#  35.2,
#  36.0,
#  36.99,
#  37.0,
#  38.0,
#  39.0,
#  39.1,
#  40.0,
#  41.0,
#  42.0,
#  43.0,
#  44.0,
#  45.0,
#  46.0,
#  47.0,
#  48.0,
#  49.0,
#  50.0,
#  51.0,
#  52.0,
#  53.0,
#  54.0,
#  55.0,
#  56.0,
#  57.0,
#  57.7,
#  58.0,
#  59.0,
#  60.0,
#  61.0,
#  62.0,
#  63.0,
#  64.0,
#  65.0,
#  66.0,
#  67.0,
#  68.0,
#  69.0,
#  69.2,
#  70.0,
#  71.0,
#  72.0,
# ...

# %%
temp.head()
# Out:
#        matrl_id  year  month  month_sale  host_nums_01  host_nums_02  \
# 14970       500  2018      1         0.0           0.0           0.0
# 14971       500  2018      2         0.0           0.0           0.0
# 14972       500  2018      3         0.0           0.0           0.0
# 14973       500  2018      4         0.0           0.0           0.0
# 14974       500  2018      5         0.0           0.0           0.0
#
#        host_nums_03  host_nums_04  host_nums_05  host_nums_07  ...  \
# 14970           0.0           0.0           0.0           0.0  ...
# 14971           0.0           0.0           0.0           0.0  ...
# 14972           0.0           0.0           0.0           0.0  ...
# 14973           0.0           0.0           0.0           0.0  ...
# 14974           0.0           0.0           0.0           0.0  ...
#
#        work_time_A7  work_nums_01  work_nums_02  work_nums_03  work_nums_04  \
# ...

# %%
temp
# Out:
#        matrl_id  year  month  month_sale  host_nums_01  host_nums_02  \
# 23970       800  2018      1         2.0           0.0           0.0
# 23971       800  2018      2         0.0           0.0           0.0
# 23972       800  2018      3         2.0           0.0           0.0
# 23973       800  2018      4        12.0           0.0           0.0
# 23974       800  2018      5         5.0           0.0           0.0
# 23975       800  2018      6         4.0           0.0           0.0
# 23976       800  2018      7         3.0           0.0           0.0
# 23977       800  2018      8         5.0           0.0           0.0
# 23978       800  2018      9        12.0           0.0           0.0
# 23979       800  2018     10         7.0           0.0           0.0
# 23980       800  2018     11        13.0           0.0           0.0
# 23981       800  2018     12         1.0           0.0           0.0
# 23982       800  2019      1         5.0           0.0           0.0
# ...

# %%
fea_col
# Out:
# ['host_nums_01',
#  'host_nums_02',
#  'host_nums_03',
#  'host_nums_04',
#  'host_nums_05',
#  'host_nums_07',
#  'host_nums_08',
#  'host_nums_09',
#  'host_nums_10',
#  'host_nums_13',
#  'host_nums_18',
#  'host_nums_19',
#  'host_nums_32',
#  'host_nums_33',
#  'host_nums_34',
#  'host_nums_35',
#  'host_nums_36',
#  'host_nums_A7',
#  'month',
#  'month_sale',
#  'work_nums_01',
#  'work_nums_02',
#  'work_nums_03',
#  'work_nums_04',
#  'work_nums_05',
#  'work_nums_33',
#  'work_nums_34',
#  'work_nums_35',
#  'work_nums_A7',
#  'work_time_01',
#  'work_time_02',
#  'work_time_03',
#  'work_time_04',
#  'work_time_05',
#  'work_time_33',
#  'work_time_34',
#  'work_time_35',
#  'work_time_A7']

# %%
fea_col = ['month_sale','host_nums_05','work_nums_05','host_nums_36','host_nums_A7','work_nums_03','work_time_05']
temp = main_df[main_df['matrl_id']==1000]
x = np.arange(1,31)
for i, element in enumerate(fea_col):
    y = temp[element]
    plt.subplot(3, 3, i+1)
    plt.plot(x,y)

# %%
temp = main_df[main_df['matrl_id']==800]
x = np.arange(1,13) 

y = temp['month_sale'].iloc[0:12]
plt.subplot(1, 3, 1)
plt.plot(x,y)
plt.title("plot 1")

#plot 2:
y = temp['month_sale'].iloc[12:24]
plt.subplot(1, 3, 2)
plt.plot(x,y)
plt.title("plot 2")

x = np.arange(1,7) 
y = temp['month_sale'].iloc[24:]
plt.subplot(1, 3, 3)
plt.plot(x,y)
plt.title("plot 3")
# Out:
# Text(0.5, 1.0, 'plot 3')
